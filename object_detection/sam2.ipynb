# %%
from ultralytics import SAM

# Load a model
model = SAM("../object_detection/sam2_b.pt")

# Display model information (optional)
model.info()

# Segment with bounding box prompt
#results = model("path/to/image.jpg", bboxes=[100, 100, 200, 200])

# Segment with point prompt
#results = model("path/to/image.jpg", points=[150, 150], labels=[1])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from ultralytics import SAM
#       3 # Load a model
# ----> 4 model = SAM("../object_detection/sam2_b.pt")
#       6 # Display model information (optional)
#       7 model.info()
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\models\sam\model.py:47, in SAM.__init__(self, model)
#      45 if model and Path(model).suffix not in {".pt", ".pth"}:
#      46     raise NotImplementedError("SAM prediction requires pre-trained *.pt or *.pth model.")
# ---> 47 super().__init__(model=model, task="segment")
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# --> 149     self._load(model, task=task)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\models\sam\model.py:57, in SAM._load(self, weights, task)
#      49 def _load(self, weights: str, task=None):
#      50     """
#      51     Loads the specified weights into the SAM model.
#      52
#    (...)
#      55         task (str, optional): Task name. Defaults to None.
#      56     """
# ---> 57     self.model = build_sam(weights)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\models\sam\build.py:159, in build_sam(ckpt)
#     156         model_builder = sam_model_map.get(k)
#     158 if not model_builder:
# --> 159     raise FileNotFoundError(f"{ckpt} is not a supported SAM model. Available models are: \n {sam_model_map.keys()}")
#     161 return model_builder(ckpt)
#
# FileNotFoundError: ../object_detection/sam2_b.pt is not a supported SAM model. Available models are:
#  dict_keys(['sam_h.pt', 'sam_l.pt', 'sam_b.pt', 'mobile_sam.pt'])
